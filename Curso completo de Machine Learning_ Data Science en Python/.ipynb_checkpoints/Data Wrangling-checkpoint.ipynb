# %% [markdown]
# # Data Wrangling
#
# Consiste en el tratamiento y preparación de los datos que se hace con el objetivo de que sean más apropiados o manejables para la tarea que los queremos usar. Es transformar el dataset "raw" en otro mejor preparado, más fácil de utilizar o más suitable para el modelo que queremos entrenar

# %%
import pandas as pd
from pandas import read_csv

# %%
data = read_csv('datasets/customer-churn-model/Customer Churn Model.txt')
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## Extraer un subconjunto del dataset original
#
# Hay veces que no nos interesa trabajar con todas las columnas, por lo que lo óptimo es trabajar sólo con las que vayamos a usar

# %%
desired_cols = ['Account Length', 'Phone', 'Eve Charge', 'Day Calls'] 
subset = data[desired_cols]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113
